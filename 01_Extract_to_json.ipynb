# %%
import torch

# GPU 사용 가능 여부 확인
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
import os
import json
import pandas as pd
import time

# 함수 정의
def extract_final_keys_and_values(obj, prefix=''):
    if isinstance(obj, dict):
        for key, value in obj.items():
            yield from extract_final_keys_and_values(value, f"{prefix}{key}.")
    else:
        yield prefix[:-1], obj

# 작업 디렉토리 경로 설정
work_dir = "/content/drive/MyDrive/project/data/dog/json/유루증"

# 작업 디렉토리 변경
os.chdir(work_dir)

# 현재 작업 디렉토리의 모든 JSON 파일 목록 가져오기
json_files = [os.path.join(root, f) for root, dirs, files in os.walk('.') for f in files if f.endswith('.json')]
total_files = len(json_files)

# 빈 DataFrame 생성
df = pd.DataFrame()

# 시작 시간 기록
start_time = time.time()

# 진행 상황 출력
print(f"총 {total_files}개의 JSON 파일 처리 중...")

# 각 JSON 파일 열기 및 데이터프레임에 추가
for i, json_file in enumerate(json_files):
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)

            # 가장 깊은 뎁스의 키-값 쌍 추출
            final_keys_and_values = list(extract_final_keys_and_values(data))

            # 데이터프레임에 추가
            for key, value in final_keys_and_values:
                if key not in df.columns:
                    df[key] = [None] * len(df)
                df.at[json_file, key] = value

    except Exception as e:
        print(f"오류 발생: {e}. 파일 '{json_file}' 처리를 건너뜁니다.")
        continue

    # 진행 상황 출력 (100개당)
    if (i + 1) % 100 == 0 or (i + 1) == total_files:
        elapsed_time = time.time() - start_time
        remaining_time = (elapsed_time / (i+1)) * (total_files - (i+1))
        print(f"[{i+1}/{total_files}] 파일 처리 중... 총 경과 시간: {elapsed_time:.2f}초, 남은 예상 시간: {remaining_time:.2f}초")

# CSV 파일로 저장
output_file = '/content/drive/MyDrive/output_dog10.csv'
df.to_csv(output_file, index=True)

print('CSV 파일이 Google Drive에 생성되었습니다.')
# Out:
# 총 21601개의 JSON 파일 처리 중...
# [100/21601] 파일 처리 중... 총 경과 시간: 66.28초, 남은 예상 시간: 14250.77초
# [200/21601] 파일 처리 중... 총 경과 시간: 393.96초, 남은 예상 시간: 42156.18초
# [300/21601] 파일 처리 중... 총 경과 시간: 394.35초, 남은 예상 시간: 27999.98초
# [400/21601] 파일 처리 중... 총 경과 시간: 394.76초, 남은 예상 시간: 20923.35초
# [500/21601] 파일 처리 중... 총 경과 시간: 395.21초, 남은 예상 시간: 16678.45초
# [600/21601] 파일 처리 중... 총 경과 시간: 395.65초, 남은 예상 시간: 13848.29초
# [700/21601] 파일 처리 중... 총 경과 시간: 396.19초, 남은 예상 시간: 11829.76초
# [800/21601] 파일 처리 중... 총 경과 시간: 396.65초, 남은 예상 시간: 10313.35초
# [900/21601] 파일 처리 중... 총 경과 시간: 397.13초, 남은 예상 시간: 9134.32초
# [1000/21601] 파일 처리 중... 총 경과 시간: 397.65초, 남은 예상 시간: 8191.98초
# [1100/21601] 파일 처리 중... 총 경과 시간: 398.16초, 남은 예상 시간: 7420.57초
# [1200/21601] 파일 처리 중... 총 경과 시간: 398.76초, 남은 예상 시간: 6779.20초
# [1300/21601] 파일 처리 중... 총 경과 시간: 399.37초, 남은 예상 시간: 6236.57초
# [1400/21601] 파일 처리 중... 총 경과 시간: 399.89초, 남은 예상 시간: 5770.07초
# [1500/21601] 파일 처리 중... 총 경과 시간: 400.61초, 남은 예상 시간: 5368.40초
# [1600/21601] 파일 처리 중... 총 경과 시간: 401.05초, 남은 예상 시간: 5013.39초
# [1700/21601] 파일 처리 중... 총 경과 시간: 401.47초, 남은 예상 시간: 4699.77초
# [1800/21601] 파일 처리 중... 총 경과 시간: 401.89초, 남은 예상 시간: 4421.04초
# [1900/21601] 파일 처리 중... 총 경과 시간: 402.31초, 남은 예상 시간: 4171.55초
# [2000/21601] 파일 처리 중... 총 경과 시간: 402.75초, 남은 예상 시간: 3947.20초
# [2100/21601] 파일 처리 중... 총 경과 시간: 403.18초, 남은 예상 시간: 3744.02초
# [2200/21601] 파일 처리 중... 총 경과 시간: 403.62초, 남은 예상 시간: 3559.36초
# [2300/21601] 파일 처리 중... 총 경과 시간: 404.14초, 남은 예상 시간: 3391.41초
# [2400/21601] 파일 처리 중... 총 경과 시간: 404.68초, 남은 예상 시간: 3237.59초
# [2500/21601] 파일 처리 중... 총 경과 시간: 405.26초, 남은 예상 시간: 3096.33초
# [2600/21601] 파일 처리 중... 총 경과 시간: 405.80초, 남은 예상 시간: 2965.63초
# [2700/21601] 파일 처리 중... 총 경과 시간: 406.31초, 남은 예상 시간: 2844.31초
# [2800/21601] 파일 처리 중... 총 경과 시간: 406.84초, 남은 예상 시간: 2731.80초
# [2900/21601] 파일 처리 중... 총 경과 시간: 407.30초, 남은 예상 시간: 2626.55초
# [3000/21601] 파일 처리 중... 총 경과 시간: 407.76초, 남은 예상 시간: 2528.23초
# [3100/21601] 파일 처리 중... 총 경과 시간: 408.24초, 남은 예상 시간: 2436.40초
# [3200/21601] 파일 처리 중... 총 경과 시간: 408.70초, 남은 예상 시간: 2350.17초
# [3300/21601] 파일 처리 중... 총 경과 시간: 409.21초, 남은 예상 시간: 2269.40초
# [3400/21601] 파일 처리 중... 총 경과 시간: 409.76초, 남은 예상 시간: 2193.55초
# [3500/21601] 파일 처리 중... 총 경과 시간: 410.24초, 남은 예상 시간: 2121.63초
# [3600/21601] 파일 처리 중... 총 경과 시간: 410.74초, 남은 예상 시간: 2053.80초
# [3700/21601] 파일 처리 중... 총 경과 시간: 411.34초, 남은 예상 시간: 1990.09초
# [3800/21601] 파일 처리 중... 총 경과 시간: 411.96초, 남은 예상 시간: 1929.81초
# [3900/21601] 파일 처리 중... 총 경과 시간: 412.61초, 남은 예상 시간: 1872.74초
# [4000/21601] 파일 처리 중... 총 경과 시간: 413.24초, 남은 예상 시간: 1818.34초
# [4100/21601] 파일 처리 중... 총 경과 시간: 413.93초, 남은 예상 시간: 1766.89초
# [4200/21601] 파일 처리 중... 총 경과 시간: 414.63초, 남은 예상 시간: 1717.87초
# [4300/21601] 파일 처리 중... 총 경과 시간: 415.33초, 남은 예상 시간: 1671.06초
# [4400/21601] 파일 처리 중... 총 경과 시간: 416.07초, 남은 예상 시간: 1626.55초
# [4500/21601] 파일 처리 중... 총 경과 시간: 416.64초, 남은 예상 시간: 1583.31초
# [4600/21601] 파일 처리 중... 총 경과 시간: 417.19초, 남은 예상 시간: 1541.87초
# [4700/21601] 파일 처리 중... 총 경과 시간: 417.83초, 남은 예상 시간: 1502.48초
# [4800/21601] 파일 처리 중... 총 경과 시간: 418.39초, 남은 예상 시간: 1464.44초
# [4900/21601] 파일 처리 중... 총 경과 시간: 418.99초, 남은 예상 시간: 1428.07초
# [5000/21601] 파일 처리 중... 총 경과 시간: 419.57초, 남은 예상 시간: 1393.04초
# [5100/21601] 파일 처리 중... 총 경과 시간: 420.51초, 남은 예상 시간: 1360.55초
# [5200/21601] 파일 처리 중... 총 경과 시간: 421.34초, 남은 예상 시간: 1328.91초
# [5300/21601] 파일 처리 중... 총 경과 시간: 422.14초, 남은 예상 시간: 1298.35초
# [5400/21601] 파일 처리 중... 총 경과 시간: 422.71초, 남은 예상 시간: 1268.20초
# [5500/21601] 파일 처리 중... 총 경과 시간: 423.27초, 남은 예상 시간: 1239.11초
# [5600/21601] 파일 처리 중... 총 경과 시간: 423.86초, 남은 예상 시간: 1211.11초
# [5700/21601] 파일 처리 중... 총 경과 시간: 424.44초, 남은 예상 시간: 1184.05초
# [5800/21601] 파일 처리 중... 총 경과 시간: 425.04초, 남은 예상 시간: 1157.95초
# [5900/21601] 파일 처리 중... 총 경과 시간: 425.64초, 남은 예상 시간: 1132.72초
# [6000/21601] 파일 처리 중... 총 경과 시간: 426.30초, 남은 예상 시간: 1108.45초
# [6100/21601] 파일 처리 중... 총 경과 시간: 427.07초, 남은 예상 시간: 1085.26초
# [6200/21601] 파일 처리 중... 총 경과 시간: 427.94초, 남은 예상 시간: 1063.01초
# [6300/21601] 파일 처리 중... 총 경과 시간: 428.89초, 남은 예상 시간: 1041.65초
# [6400/21601] 파일 처리 중... 총 경과 시간: 429.97초, 남은 예상 시간: 1021.26초
# [6500/21601] 파일 처리 중... 총 경과 시간: 431.09초, 남은 예상 시간: 1001.52초
# [6600/21601] 파일 처리 중... 총 경과 시간: 432.09초, 남은 예상 시간: 982.08초
# [6700/21601] 파일 처리 중... 총 경과 시간: 432.87초, 남은 예상 시간: 962.71초
# [6800/21601] 파일 처리 중... 총 경과 시간: 433.53초, 남은 예상 시간: 943.63초
# [6900/21601] 파일 처리 중... 총 경과 시간: 434.17초, 남은 예상 시간: 925.04초
# [7000/21601] 파일 처리 중... 총 경과 시간: 434.82초, 남은 예상 시간: 906.98초
# [7100/21601] 파일 처리 중... 총 경과 시간: 435.50초, 남은 예상 시간: 889.46초
# [7200/21601] 파일 처리 중... 총 경과 시간: 436.16초, 남은 예상 시간: 872.38초
# [7300/21601] 파일 처리 중... 총 경과 시간: 436.87초, 남은 예상 시간: 855.85초
# [7400/21601] 파일 처리 중... 총 경과 시간: 437.59초, 남은 예상 시간: 839.75초
# [7500/21601] 파일 처리 중... 총 경과 시간: 438.30초, 남은 예상 시간: 824.06초
# [7600/21601] 파일 처리 중... 총 경과 시간: 439.00초, 남은 예상 시간: 808.74초
# [7700/21601] 파일 처리 중... 총 경과 시간: 439.72초, 남은 예상 시간: 793.83초
# [7800/21601] 파일 처리 중... 총 경과 시간: 440.40초, 남은 예상 시간: 779.22초
# [7900/21601] 파일 처리 중... 총 경과 시간: 441.13초, 남은 예상 시간: 765.05초
# [8000/21601] 파일 처리 중... 총 경과 시간: 441.87초, 남은 예상 시간: 751.24초
# [8100/21601] 파일 처리 중... 총 경과 시간: 442.66초, 남은 예상 시간: 737.83초
# [8200/21601] 파일 처리 중... 총 경과 시간: 443.64초, 남은 예상 시간: 725.03초
# [8300/21601] 파일 처리 중... 총 경과 시간: 444.65초, 남은 예상 시간: 712.56초
# [8400/21601] 파일 처리 중... 총 경과 시간: 445.67초, 남은 예상 시간: 700.39초
# [8500/21601] 파일 처리 중... 총 경과 시간: 446.81초, 남은 예상 시간: 688.66초
# [8600/21601] 파일 처리 중... 총 경과 시간: 447.82초, 남은 예상 시간: 676.99초
# [8700/21601] 파일 처리 중... 총 경과 시간: 448.55초, 남은 예상 시간: 665.15초
# [8800/21601] 파일 처리 중... 총 경과 시간: 449.34초, 남은 예상 시간: 653.63초
# [8900/21601] 파일 처리 중... 총 경과 시간: 450.12초, 남은 예상 시간: 642.36초
# [9000/21601] 파일 처리 중... 총 경과 시간: 450.92초, 남은 예상 시간: 631.34초
# [9100/21601] 파일 처리 중... 총 경과 시간: 451.76초, 남은 예상 시간: 620.59초
# [9200/21601] 파일 처리 중... 총 경과 시간: 452.59초, 남은 예상 시간: 610.06초
# [9300/21601] 파일 처리 중... 총 경과 시간: 453.38초, 남은 예상 시간: 599.69초
# [9400/21601] 파일 처리 중... 총 경과 시간: 454.21초, 남은 예상 시간: 589.55초
# [9500/21601] 파일 처리 중... 총 경과 시간: 455.01초, 남은 예상 시간: 579.59초
# [9600/21601] 파일 처리 중... 총 경과 시간: 455.84초, 남은 예상 시간: 569.85초
# [9700/21601] 파일 처리 중... 총 경과 시간: 456.64초, 남은 예상 시간: 560.25초
# [9800/21601] 파일 처리 중... 총 경과 시간: 457.45초, 남은 예상 시간: 550.85초
# [9900/21601] 파일 처리 중... 총 경과 시간: 458.59초, 남은 예상 시간: 542.02초
# [10000/21601] 파일 처리 중... 총 경과 시간: 459.79초, 남은 예상 시간: 533.40초
# [10100/21601] 파일 처리 중... 총 경과 시간: 461.05초, 남은 예상 시간: 525.01초
# [10200/21601] 파일 처리 중... 총 경과 시간: 461.97초, 남은 예상 시간: 516.37초
# [10300/21601] 파일 처리 중... 총 경과 시간: 462.86초, 남은 예상 시간: 507.84초
# [10400/21601] 파일 처리 중... 총 경과 시간: 463.73초, 남은 예상 시간: 499.45초
# [10500/21601] 파일 처리 중... 총 경과 시간: 464.60초, 남은 예상 시간: 491.19초
# [10600/21601] 파일 처리 중... 총 경과 시간: 465.48초, 남은 예상 시간: 483.08초
# [10700/21601] 파일 처리 중... 총 경과 시간: 466.38초, 남은 예상 시간: 475.14초
# [10800/21601] 파일 처리 중... 총 경과 시간: 467.26초, 남은 예상 시간: 467.31초
# [10900/21601] 파일 처리 중... 총 경과 시간: 510.66초, 남은 예상 시간: 501.34초
# [11000/21601] 파일 처리 중... 총 경과 시간: 583.43초, 남은 예상 시간: 562.27초
# [11100/21601] 파일 처리 중... 총 경과 시간: 625.08초, 남은 예상 시간: 591.35초
# [11200/21601] 파일 처리 중... 총 경과 시간: 667.40초, 남은 예상 시간: 619.79초
# [11300/21601] 파일 처리 중... 총 경과 시간: 709.27초, 남은 예상 시간: 646.56초
# [11400/21601] 파일 처리 중... 총 경과 시간: 751.25초, 남은 예상 시간: 672.24초
# [11500/21601] 파일 처리 중... 총 경과 시간: 792.78초, 남은 예상 시간: 696.33초
# [11600/21601] 파일 처리 중... 총 경과 시간: 834.72초, 남은 예상 시간: 719.66초
# [11700/21601] 파일 처리 중... 총 경과 시간: 877.00초, 남은 예상 시간: 742.15초
# [11800/21601] 파일 처리 중... 총 경과 시간: 919.61초, 남은 예상 시간: 763.82초
# [11900/21601] 파일 처리 중... 총 경과 시간: 962.26초, 남은 예상 시간: 784.45초
# [12000/21601] 파일 처리 중... 총 경과 시간: 1004.44초, 남은 예상 시간: 803.63초
# [12100/21601] 파일 처리 중... 총 경과 시간: 1046.75초, 남은 예상 시간: 821.91초
# [12200/21601] 파일 처리 중... 총 경과 시간: 1088.62초, 남은 예상 시간: 838.87초
# [12300/21601] 파일 처리 중... 총 경과 시간: 1130.39초, 남은 예상 시간: 854.78초
# [12400/21601] 파일 처리 중... 총 경과 시간: 1171.41초, 남은 예상 시간: 869.20초
# [12500/21601] 파일 처리 중... 총 경과 시간: 1214.19초, 남은 예상 시간: 884.03초
# [12600/21601] 파일 처리 중... 총 경과 시간: 1256.54초, 남은 예상 시간: 897.63초
# [12700/21601] 파일 처리 중... 총 경과 시간: 1299.03초, 남은 예상 시간: 910.45초
# [12800/21601] 파일 처리 중... 총 경과 시간: 1341.53초, 남은 예상 시간: 922.40초
# [12900/21601] 파일 처리 중... 총 경과 시간: 1383.36초, 남은 예상 시간: 933.07초
# [13000/21601] 파일 처리 중... 총 경과 시간: 1425.08초, 남은 예상 시간: 942.86초
# [13100/21601] 파일 처리 중... 총 경과 시간: 1467.18초, 남은 예상 시간: 952.10초
# [13200/21601] 파일 처리 중... 총 경과 시간: 1509.89초, 남은 예상 시간: 960.96초
# [13300/21601] 파일 처리 중... 총 경과 시간: 1552.01초, 남은 예상 시간: 968.67초
# [13400/21601] 파일 처리 중... 총 경과 시간: 1594.75초, 남은 예상 시간: 976.01초
# [13500/21601] 파일 처리 중... 총 경과 시간: 1636.04초, 남은 예상 시간: 981.75초
# [13600/21601] 파일 처리 중... 총 경과 시간: 1678.82초, 남은 예상 시간: 987.67초
# [13700/21601] 파일 처리 중... 총 경과 시간: 1720.53초, 남은 예상 시간: 992.25초
# [13800/21601] 파일 처리 중... 총 경과 시간: 1762.83초, 남은 예상 시간: 996.51초
# [13900/21601] 파일 처리 중... 총 경과 시간: 1804.50초, 남은 예상 시간: 999.74초
# [14000/21601] 파일 처리 중... 총 경과 시간: 1848.86초, 남은 예상 시간: 1003.80초
# [14100/21601] 파일 처리 중... 총 경과 시간: 1891.60초, 남은 예상 시간: 1006.30초
# [14200/21601] 파일 처리 중... 총 경과 시간: 1933.22초, 남은 예상 시간: 1007.59초
# [14300/21601] 파일 처리 중... 총 경과 시간: 1975.23초, 남은 예상 시간: 1008.47초
# [14400/21601] 파일 처리 중... 총 경과 시간: 2016.77초, 남은 예상 시간: 1008.53초
# [14500/21601] 파일 처리 중... 총 경과 시간: 2059.32초, 남은 예상 시간: 1008.50초
# [14600/21601] 파일 처리 중... 총 경과 시간: 2102.54초, 남은 예상 시간: 1008.21초
# [14700/21601] 파일 처리 중... 총 경과 시간: 2145.23초, 남은 예상 시간: 1007.09초
# [14800/21601] 파일 처리 중... 총 경과 시간: 2188.86초, 남은 예상 시간: 1005.84초
# [14900/21601] 파일 처리 중... 총 경과 시간: 2231.83초, 남은 예상 시간: 1003.73초
# [15000/21601] 파일 처리 중... 총 경과 시간: 2274.48초, 남은 예상 시간: 1000.92초
# [15100/21601] 파일 처리 중... 총 경과 시간: 2317.19초, 남은 예상 시간: 997.62초
# [15200/21601] 파일 처리 중... 총 경과 시간: 2360.40초, 남은 예상 시간: 994.01초
# [15300/21601] 파일 처리 중... 총 경과 시간: 2403.42초, 남은 예상 시간: 989.80초
# [15400/21601] 파일 처리 중... 총 경과 시간: 2447.07초, 남은 예상 시간: 985.34초
# [15500/21601] 파일 처리 중... 총 경과 시간: 2488.93초, 남은 예상 시간: 979.68초
# [15600/21601] 파일 처리 중... 총 경과 시간: 2532.36초, 남은 예상 시간: 974.15초
# [15700/21601] 파일 처리 중... 총 경과 시간: 2575.43초, 남은 예상 시간: 968.00초
# [15800/21601] 파일 처리 중... 총 경과 시간: 2619.14초, 남은 예상 시간: 961.62초
# [15900/21601] 파일 처리 중... 총 경과 시간: 2662.31초, 남은 예상 시간: 954.58초
# [16000/21601] 파일 처리 중... 총 경과 시간: 2707.44초, 남은 예상 시간: 947.77초
# [16100/21601] 파일 처리 중... 총 경과 시간: 2751.12초, 남은 예상 시간: 940.00초
# [16200/21601] 파일 처리 중... 총 경과 시간: 2795.20초, 남은 예상 시간: 931.91초
# [16300/21601] 파일 처리 중... 총 경과 시간: 2838.70초, 남은 예상 시간: 923.19초
# [16400/21601] 파일 처리 중... 총 경과 시간: 2881.66초, 남은 예상 시간: 913.87초
# [16500/21601] 파일 처리 중... 총 경과 시간: 2924.51초, 남은 예상 시간: 904.12초
# [16600/21601] 파일 처리 중... 총 경과 시간: 2967.70초, 남은 예상 시간: 894.06초
# [16700/21601] 파일 처리 중... 총 경과 시간: 3010.10초, 남은 예상 시간: 883.38초
# [16800/21601] 파일 처리 중... 총 경과 시간: 3055.31초, 남은 예상 시간: 873.13초
# [16900/21601] 파일 처리 중... 총 경과 시간: 3098.53초, 남은 예상 시간: 861.91초
# [17000/21601] 파일 처리 중... 총 경과 시간: 3143.59초, 남은 예상 시간: 850.80초
# [17100/21601] 파일 처리 중... 총 경과 시간: 3190.13초, 남은 예상 시간: 839.69초
# [17200/21601] 파일 처리 중... 총 경과 시간: 3233.99초, 남은 예상 시간: 827.49초
# [17300/21601] 파일 처리 중... 총 경과 시간: 3277.81초, 남은 예상 시간: 814.91초
# [17400/21601] 파일 처리 중... 총 경과 시간: 3321.08초, 남은 예상 시간: 801.83초
# [17500/21601] 파일 처리 중... 총 경과 시간: 3365.48초, 남은 예상 시간: 788.68초
# [17600/21601] 파일 처리 중... 총 경과 시간: 3410.00초, 남은 예상 시간: 775.19초
# [17700/21601] 파일 처리 중... 총 경과 시간: 3452.79초, 남은 예상 시간: 760.98초
# [17800/21601] 파일 처리 중... 총 경과 시간: 3496.95초, 남은 예상 시간: 746.74초
# [17900/21601] 파일 처리 중... 총 경과 시간: 3541.36초, 남은 예상 시간: 732.21초
# [18000/21601] 파일 처리 중... 총 경과 시간: 3584.71초, 남은 예상 시간: 717.14초
# [18100/21601] 파일 처리 중... 총 경과 시간: 3629.57초, 남은 예상 시간: 702.05초
# [18200/21601] 파일 처리 중... 총 경과 시간: 3674.73초, 남은 예상 시간: 686.69초
# [18300/21601] 파일 처리 중... 총 경과 시간: 3721.38초, 남은 예상 시간: 671.27초
# [18400/21601] 파일 처리 중... 총 경과 시간: 3765.27초, 남은 예상 시간: 655.03초
# [18500/21601] 파일 처리 중... 총 경과 시간: 3810.51초, 남은 예상 시간: 638.72초
# [18600/21601] 파일 처리 중... 총 경과 시간: 3855.91초, 남은 예상 시간: 622.13초
# [18700/21601] 파일 처리 중... 총 경과 시간: 3898.93초, 남은 예상 시간: 604.86초
# [18800/21601] 파일 처리 중... 총 경과 시간: 3947.80초, 남은 예상 시간: 588.18초
# [18900/21601] 파일 처리 중... 총 경과 시간: 3991.11초, 남은 예상 시간: 570.37초
# [19000/21601] 파일 처리 중... 총 경과 시간: 4035.57초, 남은 예상 시간: 552.45초
# [19100/21601] 파일 처리 중... 총 경과 시간: 4077.85초, 남은 예상 시간: 533.96초
# [19200/21601] 파일 처리 중... 총 경과 시간: 4122.09초, 남은 예상 시간: 515.48초
# [19300/21601] 파일 처리 중... 총 경과 시간: 4166.06초, 남은 예상 시간: 496.69초
# [19400/21601] 파일 처리 중... 총 경과 시간: 4210.65초, 남은 예상 시간: 477.71초
# [19500/21601] 파일 처리 중... 총 경과 시간: 4255.16초, 남은 예상 시간: 458.47초
# [19600/21601] 파일 처리 중... 총 경과 시간: 4299.03초, 남은 예상 시간: 438.90초
# [19700/21601] 파일 처리 중... 총 경과 시간: 4344.25초, 남은 예상 시간: 419.21초
# [19800/21601] 파일 처리 중... 총 경과 시간: 4387.53초, 남은 예상 시간: 399.09초
# [19900/21601] 파일 처리 중... 총 경과 시간: 4430.05초, 남은 예상 시간: 378.67초
# [20000/21601] 파일 처리 중... 총 경과 시간: 4471.80초, 남은 예상 시간: 357.97초
# [20100/21601] 파일 처리 중... 총 경과 시간: 4514.45초, 남은 예상 시간: 337.12초
# [20200/21601] 파일 처리 중... 총 경과 시간: 4558.95초, 남은 예상 시간: 316.19초
# [20300/21601] 파일 처리 중... 총 경과 시간: 4604.80초, 남은 예상 시간: 295.12초
# [20400/21601] 파일 처리 중... 총 경과 시간: 4648.85초, 남은 예상 시간: 273.69초
# [20500/21601] 파일 처리 중... 총 경과 시간: 4692.69초, 남은 예상 시간: 252.03초
# [20600/21601] 파일 처리 중... 총 경과 시간: 4735.67초, 남은 예상 시간: 230.12초
# [20700/21601] 파일 처리 중... 총 경과 시간: 4805.61초, 남은 예상 시간: 209.17초
# [20800/21601] 파일 처리 중... 총 경과 시간: 4849.86초, 남은 예상 시간: 186.77초
# [20900/21601] 파일 처리 중... 총 경과 시간: 4926.50초, 남은 예상 시간: 165.24초
# [21000/21601] 파일 처리 중... 총 경과 시간: 4969.60초, 남은 예상 시간: 142.23초
# [21100/21601] 파일 처리 중... 총 경과 시간: 5011.54초, 남은 예상 시간: 118.99초
# [21200/21601] 파일 처리 중... 총 경과 시간: 5054.30초, 남은 예상 시간: 95.60초
# [21300/21601] 파일 처리 중... 총 경과 시간: 5095.88초, 남은 예상 시간: 72.01초
# [21400/21601] 파일 처리 중... 총 경과 시간: 5138.85초, 남은 예상 시간: 48.27초
# [21500/21601] 파일 처리 중... 총 경과 시간: 5180.37초, 남은 예상 시간: 24.34초
# [21600/21601] 파일 처리 중... 총 경과 시간: 5223.10초, 남은 예상 시간: 0.24초
# [21601/21601] 파일 처리 중... 총 경과 시간: 5223.56초, 남은 예상 시간: 0.00초
# CSV 파일이 Google Drive에 생성되었습니다.

# %%
import pandas as pd

# 파일 경로 설정
file_paths = ['/content/drive/MyDrive/project/cat.csv',
              '/content/drive/MyDrive/project/concatenated_data.csv',
              '/content/drive/MyDrive/project/output_dog10.csv']

# 각 파일의 형태를 저장할 리스트 생성
shapes = []

# 모든 파일 경로를 순회하면서 각 파일의 형태를 확인하고 리스트에 추가합니다.
for file_path in file_paths:
    df = pd.read_csv(file_path)  # CSV 파일 불러오기
    shapes.append(df.shape)  # 데이터프레임의 형태를 저장

# 이어붙일 데이터프레임을 생성하기 전에 각 파일의 형태를 출력합니다.
for i, shape in enumerate(shapes):
    print(f"File {i+1}: Shape {shape}")

# 빈 리스트를 생성하여 CSV 파일에서 불러온 데이터프레임을 담을 준비를 합니다.
dfs = []

# 모든 파일 경로를 순회하면서 데이터프레임을 불러와 리스트에 추가합니다.
for file_path in file_paths:
    df = pd.read_csv(file_path)  # CSV 파일 불러오기
    dfs.append(df)  # 리스트에 데이터프레임 추가

# 모든 데이터프레임을 이어붙입니다.
result = pd.concat(dfs, ignore_index=True)

# 이어붙인 후의 데이터프레임의 형태를 확인합니다.
print("Concatenated DataFrame Shape:", result.shape)

# 결과 데이터프레임을 CSV 파일로 저장합니다. 경로는 자유롭게 지정하세요.
result.to_csv('/content/drive/MyDrive/output.csv', index=False)

# 저장이 완료되면 메시지를 출력합니다.
print("DataFrame saved as CSV file.")
# Out:
# File 1: Shape (25658, 20)
# File 2: Shape (166476, 20)
# File 3: Shape (21601, 20)
# Concatenated DataFrame Shape: (213735, 20)
# DataFrame saved as CSV file.

# %%
df = pd.read_csv('/content/drive/MyDrive/output.csv')
df.shape
# Out:
# (213735, 20)

# %%
df.tail()
# Out:
#                                                Unnamed: 0  \
# 213730  ./유/crop_D10_03668f96-60a5-11ec-8402-0a740497...
# 213731  ./유/crop_D11_03669ddb-60a5-11ec-8402-0a740497...
# 213732  ./유/crop_D14_0366c5f7-60a5-11ec-8402-0a740497...
# 213733  ./유/crop_D17_0366b7f3-60a5-11ec-8402-0a740497...
# 213734  ./유/crop_D18_0366d37e-60a5-11ec-8402-0a740497...
#
#                                images.meta.file_name images.meta.date_time  \
# 213730  D10_03668f96-60a5-11ec-8402-0a7404972c70.jpg   2021-08-19 00:00:00
# 213731  D11_03669ddb-60a5-11ec-8402-0a7404972c70.jpg   2021-08-19 00:00:00
# 213732  D14_0366c5f7-60a5-11ec-8402-0a7404972c70.jpg   2021-08-19 00:00:00
# 213733  D17_0366b7f3-60a5-11ec-8402-0a7404972c70.jpg   2021-08-19 00:00:00
# 213734  D18_0366d37e-60a5-11ec-8402-0a7404972c70.jpg   2021-08-19 00:00:00
#
#        images.meta.device  images.meta.gender  images.meta.age  \
# 213730              일반카메라                 1.0              5.0
# 213731              일반카메라                 1.0              5.0
# 213732              일반카메라                 1.0              5.0
# 213733              일반카메라                 1.0              5.0
# 213734              일반카메라                 1.0              5.0
#
#        images.meta.breed  images.meta.medical_type images.meta.width_height  \
# 213730             포메라니안                         1             [4896, 3672]
# 213731             포메라니안                         1             [4896, 3672]
# 213732             포메라니안                         1             [4896, 3672]
# 213733             포메라니안                         1             [4896, 3672]
# 213734             포메라니안                         1             [4896, 3672]
#
#        images.meta.eye_position images.meta.image_resolution  \
# 213730                      왼쪽눈                   [350, 350]
# 213731                      왼쪽눈                   [350, 350]
# 213732                      왼쪽눈                   [350, 350]
# 213733                      왼쪽눈                   [350, 350]
# 213734                      왼쪽눈                   [350, 350]
#
#                                      label.label_filename  \
# 213730  crop_D10_03668f96-60a5-11ec-8402-0a7404972c70.jpg
# 213731  crop_D11_03669ddb-60a5-11ec-8402-0a7404972c70.jpg
# 213732  crop_D14_0366c5f7-60a5-11ec-8402-0a7404972c70.jpg
# 213733  crop_D17_0366b7f3-60a5-11ec-8402-0a7404972c70.jpg
# 213734  crop_D18_0366d37e-60a5-11ec-8402-0a7404972c70.jpg
#
#         label.label_category_id  \
# 213730                        1
# 213731                        1
# 213732                        1
# 213733                        1
# 213734                        1
#
#                                          label.label_path  \
# 213730  라벨링데이터/안구/개/안구/일반/유루증/유/crop_D10_03668f96-60a5...
# 213731  라벨링데이터/안구/개/안구/일반/유루증/유/crop_D11_03669ddb-60a5...
# 213732  라벨링데이터/안구/개/안구/일반/유루증/유/crop_D14_0366c5f7-60a5...
# 213733  라벨링데이터/안구/개/안구/일반/유루증/유/crop_D17_0366b7f3-60a5...
# 213734  라벨링데이터/안구/개/안구/일반/유루증/유/crop_D18_0366d37e-60a5...
#
#         label.label_deleted                      label.label_bbox  \
# 213730                    0  [1560.65, 2076.54, 2909.41, 2201.87]
# 213731                    0   [1712.4, 1888.67, 3061.02, 2585.75]
# 213732                    0  [1504.83, 2085.62, 2772.27, 2067.61]
# 213733                    0    [1685.1, 2109.66, 3248.39, 2524.3]
# 213734                    0  [1635.88, 2184.61, 2877.41, 2165.08]
#
#        label.label_disease_nm label.label_disease_lv_1  \
# 213730                    유루증                        유
# 213731                    유루증                        유
# 213732                    유루증                        유
# 213733                    유루증                        유
# 213734                    유루증                        유
#
#        label.label_disease_lv_2 label.label_disease_lv_3
# 213730                        유                        유
# 213731                        유                        유
# 213732                        유                        유
# 213733                        유                        유
# 213734                        유                        유
